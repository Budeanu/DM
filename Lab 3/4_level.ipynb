# %% [markdown]
# ## ЕЛЕМЕНТИ DATA CLEANING

# %% [markdown]
# ### ВАРІАНТ № 4
# ### Загальні положення

# %% [markdown]
# __Мета__:
# - Опанувати деякі методи завантаження, видобутоку та очищення первинних даних
# - Застосувати на практиці набуті знання та навички програмування на Python, а саме:
#     - читання і запис даних у файли;
#     - організація циклічної оброобки даних (for .. in ..)
#     - реалізація умовної обробки (if .. elif .. else)
#     - використання методів і функцій стандартної бібліотеки Python
#
# __Вхідні дані__ : файл __aprts_data_raw.csv__, якій отримано з ресурсу _https://flatfy.lun.ua/продажа-квартир-киев_ шляхом його парсингу.
#
# Файл має наступну структуру:
#
# |    | Назва поля      | Очікуваний формат поля   |
# | -- | :-----------     | :-------------------------|
# |  1 | Ціна квартири (\$ або грн)    | дробове                  |
# |  2 | Кількість кімнат | ціле
# |  3 | Ціна за м² (\$ або грн)     | дробове
# |  4 | Поверх та всього поверхів | ціле
# | 5  | рік побудови   | ціле
# | 6  | тип будинку    | текст
# | 7  | Площа (загальна/житлова/кухні)| дробове
# | 8  | вулиця         | текст
# | 9  | номер дому     | текст
#
# __Особливі умови__: в первиних даних деякі показники можуть бути відстутні (не распарсені) - тоді вони позначаються `*** not found`

# %% [markdown]
# ### Теоретична частина та приклади

# %% [markdown]
# Вхідний файл треба зчитувати і обробляти __порядково__ -  це гарна практика роботи з великими об\`ємами даних.
#
# Дані, що зчитуються з файлів порядково представляються у текстовому (__str__) форматі, тому доцільно використовувати [функції обробки строкових даних](https://pythonworld.ru/tipy-dannyx-v-python/stroki-funkcii-i-metody-strok.html) python:

# %%
# split() - дозволяє розділити текстову строку на окремі поля і помістити їх в список

stroka = "Вася Пупкін - студент 5 курсу ФІТ"
print("Розподільник: ` `")
print (stroka)
list_from_stroka = stroka.split()
print(list_from_stroka, end='\n\n')

# якщо в якості аргумента split вказати розподільник, 
# то він буде використаний при побудові списка
list_from_stroka = stroka.split('-')
print("Розподільник: `-`")
print (stroka)
print(list_from_stroka)

# %% [markdown]
# __Примітка:__ файли в csv-форматі мають в якості розподільника, як правило, символ `,`

# %%
# за допомогою метода strip() є можливість "обрізати" зліва та справа пробіли 
# (якщо параметер не вказано), або символи, які вказані в якостиі параметрів:

stroka = "     Вася Пупкін - студент 5 курсу ФІТ   "
striped_stroka = stroka.strip()
print(stroka)
print(striped_stroka)
print(striped_stroka.strip('ФІТ'))

# %% [markdown]
# __Конвертування строкових даних__ у чисельні здійснюється за допомогою функцій [int](https://pythoner.name/int-function) або [float](https://www.programiz.com/python-programming/methods/built-in/float), але треба мати на увазі що ці функціі викинуть виключення, якщо буде спроба конвертувати не число. Тому перед виконанням конвертування доцільно перевіряти, чи буде воно успішнім. Для цього можна викорастати функцію [isnumeric](https://pythonz.net/references/named/str.isnumeric/).

# %%
# 
number_str = '123.3'
print(type(number_str))
number_float = float(number_str)
print(type(number_float), end='\n\n')

# але
maybe_number_str = '123.З' # після крапки не число!
print(type(number_str))
# number_float = float(maybe_number_str) # ValueError: could not convert string to float: '123.З'

# треба
if maybe_number_str.isnumeric():
    #  True
    number_float = float(maybe_number_str)
else:
    # False
    # код який обробляє цю ситуацію
    ...

# %% [markdown]
# ### Приклад розбору рядків, та вилучення показчиків

# %%
# Припустимо, що ми маємо файл, вміст якого відображається на список:
file_content = [
    'Вася Пупкін ,  5 курс, ФІТ',
    'Петя Сидоров, 1 курс, ФТМ',
    ' Вова   Хлопов , 3 курс, ФІТ'
]
_ = [print(x) for x in file_content]

# %%
# треба створити новий список, який буде містити окремо ім'я та прізвище

# зарезервуєм пустий контейнер
name_and_surname = []

for line in file_content:
    list_from_line = line.split(',')
    name, surname = list_from_line[0].split()
    name_and_surname += [[name.strip(), surname.strip()]]

_ = [print(x) for x in name_and_surname]

# %%
# теж саме в функціональному стилі 
from functools import reduce
reduce(lambda acc, line: acc + [line.split(',')[0].split()], file_content, [])

# %% [markdown]
# ### ЗАВДАННЯ
#
# <p style="background-color: lightblue; padding:10px">На основі вхідного файлу <b>aprts_data_raw.csv</b> побудувати вихідний файл <b>aprt_level.txt</b> кожний рядок якого є вилучене з 4 показника та приведене до очікуваного формату значення поверху на якому розташована квартира.<br><br><i>При неможливості приведення показчика його треба замінити на 0</i></p>

# %% [markdown]
# _Фрагмент_ результатного файлу:
#
# `
# 21
# 11
# 5
# 5
# ...
# `

# %%
import csv
with open("aprts_data_raw.csv ", encoding='utf-8') as file, \
     open('aprt_total_area.txt', 'w', encoding='utf-8') as file2:
    file_read = csv.reader(file, delimiter = ",")
    count = 0
    for line in file_read:
        if line[3] == ' not exist ':
            line[3] = '0'
            print(f'{line[3].strip()} ; {line[4]}.')
            file2.write(f'{line[3]} ; {line[4]}. \n')
        elif line[3] < '30':
            line[3] = '1'
            print(f'{line[3].strip()} ; {line[4]}.')
            file2.write(f'{line[3]} ; {line[4]}. \n')
        else:
            print(f'{line[3]} ; {line[4]}.')
            file2.write(f'{line[3]} ; {line[4]}. \n')
    count += 1
# Out:
# 1 ; год постройки2015.
# 1 ; *** not found .
# 5 из 18 ; год постройки2011.
# 5 из 5 ; год постройки1902.
# 1 ; год постройки2014.
# 1 ; год постройки2009.
# 1 ; год постройки2018.
# 4 из 23 ; год постройки2012.
# 6 из 20 ; год постройки2017.
# 1 ; год постройки1980.
# 8 из 19 ; год постройки2012.
# 1 ; *** not found .
# 1 ; год постройки2018.
# 1 ; год постройки1985.
# 1 ; год постройки2017.
# 5 из 9 ; год постройки1981.
# 1 ; год постройки2016.
# 4 из 6 ; *** not found .
# 1 ; год постройки1987.
# 1 ; *** not found .
# 1 ; год постройки2016.
# 8 из 9 ; год постройки1976.
# 5 из 5 ; год постройки1960.
# 5 из 5 ; год постройки1966.
# 1 ; год постройки1964.
# 7 из 12 ; год постройки2008.
# 1 ; *** not found .
# 6 из 25 ; *** not found .
# 1 ; год постройки2007.
# 1 ; год постройки1916.
# 7 из 16 ; *** not found .
# 1 ; *** not found .
# 6 из 16 ; год постройки2013.
# 1 ; год постройки2019.
# 1 ; *** not found .
# 1 ; год постройки2009.
# 5 из 25 ; год постройки2017.
# 9 из 12 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2016.
# 1 ; год постройки1986.
# 1 ; год постройки2019.
# 9 из 9 ; год постройки1977.
# 1 ; *** not found .
# 1 ; год постройки2018.
# 1 ; год постройки1983.
# 1 ; *** not found .
# 5 из 5 ; год постройки1963.
# 1 ; год постройки2014.
# 4-этажный дом ; год постройки1906.
# 5 из 5 ; год постройки1962.
# 1 ; *** not found .
# 1 ; год постройки2017.
# 1 ; год постройки2009.
# 1 ; год постройки2002.
# 1 ; год постройки1990.
# 7 из 9 ; год постройки1971.
# 6 из 24 ; год постройки2010.
# 9 из 9 ; год постройки1969.
# 1 ; *** not found .
# 9 из 9 ; год постройки1983.
# 1 ; год постройки1892.
# 1 ; *** not found .
# 1 ; год постройки2006.
# 5 из 9 ; год постройки2017.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2008.
# 4 из 25 ; год постройки2010.
# 1 ; год постройки1990.
# 1 ; год постройки2018.
# 1 ; год постройки2014.
# 4-этажный дом ; год постройки1906.
# 5 из 5 ; год постройки1962.
# 1 ; *** not found .
# 1 ; год постройки2017.
# 1 ; год постройки2009.
# 1 ; год постройки2002.
# 1 ; год постройки1990.
# 7 из 9 ; год постройки1971.
# 6 из 24 ; год постройки2010.
# 9 из 9 ; год постройки1969.
# 1 ; *** not found .
# 9 из 9 ; год постройки1983.
# 1 ; год постройки1892.
# 1 ; *** not found .
# 1 ; год постройки2006.
# 5 из 9 ; год постройки2017.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2008.
# 4 из 25 ; год постройки2010.
# 1 ; год постройки1990.
# 1 ; год постройки2018.
# 6 из 6 ; год постройки1994.
# 7 из 22 ; год постройки2016.
# 1 ; год постройки2014.
# 1 ; год постройки1959.
# 5 из 16 ; год постройки1990.
# 1 ; год постройки1962.
# 1 ; год постройки2017.
# 1 ; год постройки2013.
# 1 ; *** not found .
# 7 из 25 ; год постройки1969.
# 1 ; *** not found .
# 4 из 5 ; год постройки2020.
# 6 из 22 ; *** not found .
# 9 из 27 ; год постройки2004.
# 4 из 22 ; год постройки2008.
# 1 ; год постройки2018.
# 5 из 25 ; год постройки2013.
# 1 ; *** not found .
# 1 ; год постройки2017.
# 5 из 24 ; год постройки2020.
# 1 ; год постройки2011.
# 1 ; *** not found .
# 8 из 9 ; год постройки2018.
# 9 из 25 ; год постройки2019.
# 1 ; год постройки2019.
# 1 ; год постройки1957.
# 7 из 12 ; год постройки2001.
# 5 из 16 ; год постройки2017.
# 1 ; год постройки2018.
# 1 ; год постройки2013.
# 1 ; год постройки2007.
# 1 ; *** not found .
# 4 из 5 ; год постройки2020.
# 1 ; *** not found .
# 6 из 10 ; год постройки2013.
# 4 из 20 ; год постройки2015.
# 1 ; *** not found .
# 9 из 9 ; год постройки1963.
# 1 ; год постройки2019.
# 1 ; год постройки2013.
# 1 ; *** not found .
# 1 ; год постройки2018.
# 6 из 9 ; год постройки1981.
# 4 из 4 ; *** not found .
# 1 ; год постройки2015.
# 8 из 11 ; год постройки2005.
# 1 ; год постройки2003.
# 1 ; *** not found .
# 1 ; год постройки2019.
# 1 ; год постройки1971.
# 7 из 25 ; *** not found .
# 1 ; год постройки1980.
# 1 ; год постройки1959.
# 1 ; год постройки2014.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1980.
# 7 из 8 ; год постройки2019.
# 1 ; год постройки1993.
# 1 ; год постройки2003.
# 1 ; год постройки2017.
# 5 из 22 ; год постройки1996.
# 1 ; *** not found .
# 1 ; *** not found .
# 6 из 6 ; год постройки1914.
# 1 ; год постройки2005.
# 9 из 16 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1999.
# 4 из 5 ; год постройки2007.
# 1 ; год постройки2009.
# 1 ; год постройки2014.
# 5 из 11 ; год постройки2005.
# 5 из 16 ; год постройки2017.
# 7 из 14 ; год постройки2007.
# 9 из 16 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2015.
# 1 ; *** not found .
# 1 ; год постройки2014.
# 6 из 9 ; год постройки1977.
# 6 из 9 ; год постройки1974.
# 5 из 24 ; год постройки2005.
# 8 из 8 ; год постройки1958.
# 1 ; *** not found .
# 1 ; год постройки2017.
# 1 ; год постройки2018.
# 1 ; год постройки2005.
# 7 из 22 ; год постройки2012.
# 1 ; год постройки1964.
# 1 ; год постройки2015.
# 1 ; год постройки2017.
# 1 ; *** not found .
# 1 ; год постройки2011.
# 1 ; год постройки1964.
# 1 ; год постройки2016.
# 7 из 26 ; *** not found .
# 1 ; год постройки2021.
# 1 ; год постройки1946.
# 9 из 24 ; год постройки2017.
# 5 из 9 ; год постройки1977.
# 1 ; год постройки2018.
# 4 из 6 ; *** not found .
# 1 ; год постройки2013.
# 7 из 25 ; год постройки2015.
# 1 ; год постройки2001.
# 1 ; *** not found .
# 8 из 25 ; год постройки2015.
# 6 из 6 ; *** not found .
# 1 ; год постройки2003.
# 1 ; год постройки1963.
# 1 ; год постройки1962.
# 4 из 6 ; год постройки1895.
# 1 ; *** not found .
# 4 из 16 ; *** not found .
# 1 ; год постройки2001.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1970.
# 8 из 9 ; год постройки1973.
# 1 ; *** not found .
# 1 ; год постройки2010.
# 1 ; *** not found .
# 6 из 9 ; год постройки1979.
# 4 из 16 ; год постройки2002.
# 1 ; год постройки2018.
# 1 ; год постройки2005.
# 1 ; *** not found .
# 9 из 24 ; год постройки2019.
# 6 из 9 ; год постройки1975.
# 1 ; год постройки2010.
# 1 ; год постройки2005.
# 9 из 25 ; год постройки2020.
# 9 из 9 ; год постройки1986.
# 1 ; *** not found .
# 1 ; год постройки2005.
# 1 ; год постройки2018.
# 1 ; год постройки2011.
# 1 ; год постройки2018.
# 1 ; год постройки1971.
# 1 ; год постройки2020.
# 4 из 5 ; год постройки1960.
# 1 ; год постройки2005.
# 1 ; *** not found .
# 1 ; год постройки2006.
# 4 из 9 ; год постройки1969.
# 1 ; год постройки2015.
# 1 ; *** not found .
# 1 ; год постройки2006.
# 1 ; год постройки2019.
# 1 ; *** not found .
# 1 ; год постройки2007.
# 4 из 14 ; *** not found .
# 9 из 9 ; год постройки1973.
# 1 ; год постройки2012.
# 1 ; год постройки2017.
# 1 ; год постройки1997.
# 5 из 6 ; год постройки1936.
# 6 из 16 ; год постройки2005.
# 1 ; год постройки1971.
# 4 из 26 ; *** not found .
# 1 ; год постройки1883.
# 8 из 27 ; год постройки2010.
# 6 из 12 ; год постройки2016.
# 6 из 25 ; год постройки2016.
# 1 ; год постройки2001.
# 1 ; *** not found .
# 6 из 8 ; год постройки2015.
# 5 из 19 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 4 из 5 ; *** not found .
# 5 из 26 ; *** not found .
# 5 из 23 ; год постройки2013.
# 1 ; *** not found .
# 1 ; *** not found .
# 7 из 9 ; *** not found .
# 5 из 9 ; год постройки1982.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1983.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2013.
# 9 из 20 ; год постройки2014.
# 1 ; год постройки2013.
# 1 ; год постройки2019.
# 1 ; *** not found .
# 4 из 4 ; год постройки1905.
# 8 из 9 ; *** not found .
# 1 ; год постройки2012.
# 1 ; год постройки1959.
# 1 ; год постройки2016.
# 1 ; *** not found .
# 9 из 13 ; *** not found .
# 9 из 9 ; год постройки1973.
# 5 из 25 ; *** not found .
# 1 ; год постройки2009.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2003.
# 6 из 9 ; год постройки1971.
# 9 из 24 ; *** not found .
# 1 ; год постройки1983.
# 1 ; *** not found .
# 1 ; год постройки2015.
# 1 ; год постройки1982.
# 1 ; *** not found .
# 4 из 5 ; год постройки1961.
# 5 из 24 ; год постройки2019.
# 1 ; *** not found .
# 1 ; *** not found .
# 6 из 26 ; год постройки2018.
# 7 из 25 ; год постройки2016.
# 1 ; год постройки2020.
# 1 ; год постройки2018.
# 1 ; год постройки2012.
# 9 из 17 ; год постройки2006.
# 1 ; год постройки1989.
# 1 ; *** not found .
# 1 ; год постройки2015.
# 8 из 24 ; год постройки2014.
# 1 ; *** not found .
# 1 ; год постройки2004.
# 1 ; *** not found .
# 1 ; год постройки2018.
# 4 из 25 ; год постройки2012.
# 9 из 12 ; год постройки2015.
# 1 ; год постройки2018.
# 5 из 9 ; год постройки1977.
# 1 ; год постройки2012.
# 4 из 22 ; год постройки2006.
# 1 ; год постройки2015.
# 1 ; год постройки1966.
# 9 из 9 ; год постройки2019.
# 1 ; год постройки2018.
# 1 ; *** not found .
# 1 ; *** not found .
# 9 из 10 ; год постройки2014.
# 1 ; *** not found .
# 4 из 4 ; *** not found .
# 1 ; год постройки2017.
# 1 ; год постройки2018.
# 1 ; год постройки1879.
# 9 из 10 ; год постройки1991.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1961.
# 1 ; год постройки2017.
# 8 из 16 ; *** not found .
# 1 ; год постройки1913.
# 1 ; *** not found .
# 6 из 7 ; *** not found .
# 1 ; год постройки1999.
# 1 ; год постройки1961.
# 1 ; *** not found .
# 1 ; *** not found .
# 6 из 9 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2013.
# 1 ; год постройки2013.
# 1 ; *** not found .
# 7 из 16 ; год постройки1993.
# 1 ; *** not found .
# 1 ; год постройки2016.
# 1 ; год постройки2018.
# 7 из 9 ; *** not found .
# 7 из 23 ; год постройки2015.
# 1 ; год постройки2019.
# 6 из 25 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2010.
# 1 ; год постройки2005.
# 4 из 8 ; год постройки2011.
# 6 из 25 ; год постройки2007.
# 4 из 24 ; год постройки2009.
# 8 из 26 ; *** not found .
# 6 из 10 ; год постройки2003.
# 5 из 25 ; год постройки2014.
# 1 ; год постройки1999.
# 1 ; год постройки2018.
# 5 из 24 ; год постройки2020.
# 6 из 26 ; год постройки2018.
# 7 из 9 ; год постройки1972.
# 1 ; год постройки2018.
# 1 ; год постройки2011.
# 1 ; год постройки2019.
# 1 ; *** not found .
# 1 ; год постройки2007.
# 1 ; *** not found .
# 9 из 9 ; год постройки1978.
# 1 ; год постройки1858.
# 1 ; год постройки1974.
# 9 из 26 ; год постройки2017.
# 1 ; *** not found .
# 1 ; год постройки2008.
# 1 ; *** not found .
# 1 ; *** not found .
# 8 из 15 ; год постройки2007.
# 9 из 10 ; год постройки2014.
# 8 из 32 ; год постройки2016.
# 1 ; год постройки1993.
# 7 из 9 ; год постройки1978.
# 5 из 12 ; *** not found .
# 1 ; год постройки2016.
# 1 ; год постройки1936.
# 1 ; *** not found .
# 1 ; год постройки2005.
# 4 из 5 ; год постройки1959.
# 7 из 16 ; год постройки2001.
# 1 ; год постройки2015.
# 1 ; год постройки1988.
# 4 из 9 ; год постройки1981.
# 5 из 5 ; год постройки1936.
# 8 из 26 ; год постройки2019.
# 4 из 26 ; год постройки2005.
# 1 ; *** not found .
# 1 ; год постройки1965.
# 1 ; год постройки2018.
# 1 ; *** not found .
# 1 ; год постройки2010.
# 1 ; год постройки2014.
# 4 из 8 ; год постройки2016.
# 1 ; год постройки2002.
# 1 ; *** not found .
# 8 из 9 ; *** not found .
# 1 ; год постройки1963.
# 1 ; год постройки2005.
# 1 ; год постройки2016.
# 7 из 19 ; год постройки2018.
# 4 из 24 ; год постройки2015.
# 1 ; год постройки1985.
# 1 ; год постройки2007.
# 1 ; год постройки2010.
# 9 из 16 ; *** not found .
# 1 ; год постройки2014.
# 8 из 10 ; *** not found .
# 9 из 9 ; год постройки1970.
# 1 ; год постройки1975.
# 1 ; год постройки2014.
# 1 ; год постройки2012.
# 1 ; год постройки2019.
# 8 из 10 ; *** not found .
# 5 из 16 ; год постройки1974.
# 9 из 19 ; год постройки2019.
# 1 ; год постройки1975.
# 4 из 16 ; год постройки2002.
# 1 ; год постройки1998.
# 1 ; год постройки2016.
# 1 ; год постройки2016.
# 1 ; год постройки2012.
# 1 ; *** not found .
# 1 ; год постройки2008.
# 4 из 9 ; год постройки2013.
# 4 из 9 ; год постройки1969.
# 1 ; год постройки2020.
# 1 ; год постройки1913.
# 1 ; год постройки2017.
# 1 ; год постройки2017.
# 1 ; год постройки2020.
# 6 из 26 ; *** not found .
# 1 ; год постройки1954.
# 5 из 5 ; *** not found .
# 5 из 6 ; год постройки1936.
# 1 ; год постройки2016.
# 1 ; год постройки2018.
# 6 из 25 ; *** not found .
# 1 ; год постройки2019.
# 1 ; год постройки2014.
# 1 ; *** not found .
# 8 из 19 ; *** not found .
# 1 ; год постройки2003.
# 6 из 17 ; год постройки2009.
# 1 ; год постройки1964.
# 1 ; год постройки1986.
# 1 ; *** not found .
# 9 из 17 ; год постройки2011.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2018.
# 1 ; *** not found .
# 7 из 25 ; *** not found .
# 4 из 17 ; год постройки2010.
# 1 ; год постройки2017.
# 1 ; год постройки2017.
# 1 ; *** not found .
# 4 из 5 ; год постройки1955.
# 1 ; *** not found .
# 1 ; год постройки2018.
# 1 ; год постройки2014.
# 1 ; *** not found .
# 7 из 13 ; *** not found .
# 1 ; год постройки2015.
# 8 из 9 ; год постройки2002.
# 7 из 25 ; год постройки2016.
# 1 ; год постройки2019.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2019.
# 1 ; *** not found .
# 1 ; год постройки1975.
# 1 ; год постройки2017.
# 1 ; год постройки2010.
# 6 из 9 ; год постройки1977.
# 1 ; год постройки2019.
# 9 из 26 ; *** not found .
# 1 ; год постройки2019.
# 1 ; год постройки2013.
# 1 ; год постройки2018.
# 8 из 22 ; год постройки2019.
# 1 ; год постройки2018.
# 1 ; год постройки2009.
# 4 из 5 ; *** not found .
# 1 ; год постройки1961.
# 1 ; год постройки2003.
# 1 ; год постройки2018.
# 1 ; год постройки2008.
# 4 из 9 ; год постройки1967.
# 4 из 10 ; год постройки2017.
# 1 ; год постройки1936.
# 1 ; *** not found .
# 9 из 25 ; год постройки2010.
# 1 ; год постройки2019.
# 1 ; год постройки2013.
# 1 ; год постройки2012.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2013.
# 4 из 11 ; *** not found .
# 4 из 15 ; год постройки2009.
# 1 ; год постройки1985.
# 7 из 24 ; год постройки2018.
# 1 ; год постройки1989.
# 1 ; год постройки2019.
# 9 из 14 ; год постройки1998.
# 1 ; год постройки2013.
# 1 ; год постройки2008.
# 1 ; год постройки2015.
# 7 из 16 ; год постройки2019.
# 1 ; *** not found .
# 1 ; год постройки2018.
# 7 из 12 ; год постройки2006.
# 9 из 9 ; год постройки1972.
# 1 ; год постройки1976.
# 1 ; год постройки1914.
# 8 из 11 ; *** not found .
# 4 из 25 ; *** not found .
# 1 ; год постройки2008.
# 1 ; год постройки2017.
# 4 из 9 ; год постройки1973.
# 1 ; год постройки1956.
# 1 ; год постройки2020.
# 6 из 9 ; год постройки1981.
# 1 ; *** not found .
# 1 ; *** not found .
# 9 из 24 ; *** not found .
# 1 ; год постройки2005.
# 4 из 4 ; год постройки1940.
# 1 ; *** not found .
# 6 из 12 ; год постройки1976.
# 1 ; год постройки2018.
# 1 ; год постройки2010.
# 8 из 25 ; год постройки2022.
# 1 ; год постройки2006.
# 5 из 8 ; год постройки1957.
# 6 из 25 ; год постройки2019.
# 4 из 18 ; год постройки2004.
# 1 ; год постройки2016.
# 9 из 9 ; год постройки1977.
# 1 ; *** not found .
# 5 из 9 ; год постройки1973.
# 9 из 11 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2015.
# 1 ; год постройки2018.
# 4 из 5 ; год постройки1910.
# 1 ; *** not found .
# 1 ; год постройки1967.
# 1 ; год постройки1972.
# 1 ; год постройки2010.
# 1 ; *** not found .
# 5 из 12 ; год постройки2013.
# 1 ; год постройки2013.
# 5 из 5 ; год постройки1961.
# 8 из 27 ; год постройки2017.
# 1 ; *** not found .
# 7 из 10 ; год постройки2005.
# 1 ; год постройки2017.
# 1 ; год постройки2007.
# 1 ; *** not found .
# 1 ; год постройки1955.
# 1 ; год постройки2020.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2013.
# 4 из 14 ; год постройки2013.
# 7 из 9 ; год постройки1977.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1954.
# 9 из 9 ; год постройки1972.
# 1 ; *** not found .
# 7 из 20 ; год постройки2018.
# 1 ; год постройки2018.
# 1 ; год постройки1957.
# 1 ; год постройки2009.
# 1 ; *** not found .
# 9 из 9 ; год постройки2019.
# 1 ; *** not found .
# 1 ; *** not found .
# 7 из 15 ; год постройки2005.
# 1 ; год постройки2018.
# 4 из 19 ; год постройки2017.
# 4 из 8 ; год постройки2011.
# 1 ; *** not found .
# 5 из 9 ; год постройки1977.
# 1 ; год постройки2015.
# 1 ; год постройки1987.
# 7 из 10 ; *** not found .
# 1 ; год постройки1995.
# 1 ; год постройки2005.
# 1 ; год постройки1961.
# 4 из 14 ; год постройки2000.
# 5 из 25 ; год постройки2008.
# 1 ; год постройки2018.
# 1 ; год постройки2014.
# 9 из 30 ; *** not found .
# 4 из 6 ; *** not found .
# 7 из 20 ; год постройки2010.
# 1 ; год постройки1966.
# 1 ; *** not found .
# 1 ; год постройки2005.
# 1 ; год постройки2015.
# 4 из 26 ; *** not found .
# 5 из 5 ; год постройки1962.
# 1 ; год постройки2015.
# 1 ; год постройки2012.
# 1 ; год постройки1903.
# 1 ; год постройки1998.
# 1 ; год постройки2016.
# 1 ; год постройки2020.
# 4 из 5 ; год постройки1938.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1966.
# 1 ; год постройки1937.
# 6 из 17 ; год постройки2019.
# 1 ; год постройки2019.
# 1 ; *** not found .
# 8 из 26 ; год постройки2019.
# 1 ; год постройки1985.
# 1 ; *** not found .
# 6 из 9 ; год постройки1981.
# 1 ; *** not found .
# 1 ; год постройки2011.
# 4 из 25 ; *** not found .
# 1 ; год постройки1983.
# 1 ; *** not found .
# 9 из 26 ; *** not found .
# 1 ; год постройки2018.
# 1 ; *** not found .
# 5 из 27 ; год постройки2019.
# 1 ; год постройки2004.
# 1 ; год постройки2014.
# 4 из 16 ; год постройки2017.
# 1 ; год постройки2000.
# 9 из 21 ; год постройки2004.
# 1 ; год постройки2012.
# 1 ; *** not found .
# 1 ; год постройки2019.
# 9 из 26 ; год постройки2017.
# 9 из 17 ; год постройки2001.
# 1 ; год постройки1948.
# 9 из 13 ; *** not found .
# 1 ; год постройки2013.
# 1 ; год постройки2018.
# 9 из 9 ; год постройки2018.
# 1 ; год постройки2017.
# 1 ; год постройки2010.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1987.
# 1 ; год постройки2018.
# 1 ; год постройки1973.
# 6 из 9 ; год постройки1969.
# 1 ; год постройки2015.
# 1 ; год постройки2016.
# 1 ; год постройки2014.
# 1 ; *** not found .
# 5 из 5 ; год постройки1965.
# 1 ; год постройки2016.
# 1 ; год постройки2004.
# 1 ; *** not found .
# 1 ; год постройки2011.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки2019.
# 1 ; год постройки2019.
# 8 из 26 ; *** not found .
# 1 ; год постройки2008.
# 1 ; *** not found .
# 6 из 25 ; год постройки2018.
# 1 ; год постройки2016.
# 8 из 34 ; *** not found .
# 1 ; год постройки2006.
# 1 ; *** not found .
# 8 из 26 ; год постройки2019.
# 1 ; *** not found .
# 1 ; год постройки1963.
# 1 ; год постройки2014.
# 1 ; год постройки2017.
# 1 ; год постройки1911.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1969.
# 1 ; *** not found .
# 5 из 9 ; год постройки1967.
# 4 из 27 ; год постройки2019.
# 1 ; год постройки2019.
# 6 из 9 ; год постройки1965.
# 9 из 16 ; год постройки2020.
# 1 ; год постройки2012.
# 1 ; *** not found .
# 5 из 5 ; год постройки1963.
# 1 ; год постройки1995.
# 1 ; *** not found .
# 7 из 11 ; *** not found .
# 5 из 5 ; год постройки1959.
# 6 из 25 ; год постройки2014.
# 1 ; год постройки2013.
# 7 из 25 ; *** not found .
# 9 из 21 ; год постройки2014.
# 4 из 25 ; год постройки2017.
# 4 из 4 ; год постройки1917.
# 5 из 8 ; год постройки2019.
# 6 из 25 ; *** not found .
# 9 из 26 ; *** not found .
# 1 ; год постройки2008.
# 1 ; *** not found .
# 5 из 5 ; год постройки1962.
# 1 ; год постройки2014.
# 1 ; год постройки2018.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 5 из 9 ; год постройки1977.
# 5 из 16 ; год постройки2006.
# 1 ; *** not found .
# 1 ; год постройки2017.
# 1 ; год постройки1972.
# 7 из 10 ; год постройки2018.
# 1 ; *** not found .
# 1 ; год постройки1977.
# 1 ; *** not found .
# 5 из 25 ; *** not found .
# 6 из 24 ; *** not found .
# 1 ; *** not found .
# 4 из 10 ; год постройки2016.
# 1 ; год постройки1987.
# 1 ; год постройки2020.
# 1 ; *** not found .
# 1 ; год постройки2007.
# 8 из 18 ; год постройки1993.
# 4 из 25 ; *** not found .
# 9 из 11 ; *** not found .
# 5 из 21 ; год постройки2011.
# 1 ; год постройки2006.
# 1 ; *** not found .
# 6 из 17 ; год постройки2001.
# 9 из 10 ; год постройки1994.
# 1 ; *** not found .
# 5 из 7 ; год постройки1959.
# 1 ; *** not found .
# 6 из 9 ; год постройки1986.
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; *** not found .
# 1 ; год постройки1997.
# 1 ; год постройки2012.
# 1 ; год постройки2016.
# 5 из 10 ; год постройки2001.
# 1 ; *** not found .
# 1 ; *** not found .
# 5 из 5 ; год постройки1917.
# 1 ; год постройки2017.
# 1 ; год постройки1990.
# 9 из 19 ; год постройки2007.
# 1 ; год постройки1977.
# 1 ; *** not found .
# 1 ; год постройки2021.
# 7 из 10 ; год постройки2010.
# 1 ; год постройки1997.
# 7 из 8 ; год постройки2013.
# 7 из 16 ; *** not found .
# 1 ; год постройки2016.
